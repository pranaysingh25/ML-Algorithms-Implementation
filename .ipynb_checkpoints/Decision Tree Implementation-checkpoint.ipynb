# %%
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()
X_train = iris.data
y_train = iris.target
X_train = np.column_stack((X_train, iris.target))
features = iris.feature_names

# %%
target_names = iris.target_names
label = list(target_names)
label
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value
    
    def match(self, sample):
        return (sample[self.column] >= self.value)
    
    def __repr__(self):
        return 'Is %s %s %s?' % (features[self.column], '>=' , str(self.value))

# %%
def partition(rows, question):
    
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
        
    return true_rows, false_rows

# %%
def class_counts(rows):
    
    counts = {}
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    
    return counts

# %%
class_counts(X_train)
# Out:
# {0.0: 50, 1.0: 50, 2.0: 50}

# %%
def gini(rows):
    
    counts = class_counts(rows)
    impurity = 1
    for i in counts:
        probability = counts[i] / len(rows)
        impurity = impurity - (probability)**2
    
    return impurity

# %%
gini(X_train)
# Out:
# 0.6666666666666665

# %%
def info_gain(left, right, curr_impurity):
    
    l = float(len(left)) / len(left) + len(right)
    return curr_impurity - l*gini(left) - (1-l)*gini(right)

# %%
def best_split(rows):
    features = len(rows[0]) - 1
    curr_impurity = gini(rows)
    best_gain = 0
    best_question = None
    
    for col in range(features):     #for every feature(column)
        value_set = set([row[col] for row in rows])
        for val in value_set:
            question = Question(col, val)
            true_rows, false_rows = partition(rows, question)
            
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue
        
            gain = info_gain(true_rows, false_rows, curr_impurity)
            if gain >= best_gain:
                best_gain, best_question = gain, question
            
    return best_gain, best_question

# %%
bg, bq = best_split(X_train)

# %%
print(bg)
print(bq)
# Out:
# 99.99552572706934
# Is petal length (cm) >= 6.9?

# %%
class leaf:
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
def build_tree(rows):
    info, question = best_split(rows)
    
    if info == 0:
        return leaf(rows)
    
    true_rows, false_rows = partition(rows, question)
    #recursion
    true_subtree = build_tree(true_rows)
    false_subtree = build_tree(false_rows)
    
    return Decision_Node(question, true_subtree, false_subtree)

# %%
class Decision_Node:
    def __init__(self, question, true_subtree, false_subtree):
        self.question = question
        self.true_subtree = true_subtree
        self.false_subtree = false_subtree

# %%
def print_tree(node, spacing=""):
    if isinstance(node, leaf):   #base case
        print (spacing + "Predict", node.predictions)
        return

    print (spacing + str(node.question))

    print (spacing + '--> True:')
    print_tree(node.true_subtree, spacing + "  ")

    
    print (spacing + '--> False:')
    print_tree(node.false_subtree, spacing + "  ")

# %%
iris_dt = build_tree(X_train)

# %%
print_tree(iris_dt)
# Out:
# Is petal length (cm) >= 6.9?
# --> True:
#   Predict {2.0: 1}
# --> False:
#   Is sepal width (cm) >= 4.4?
#   --> True:
#     Predict {0.0: 1}
#   --> False:
#     Is sepal width (cm) >= 4.2?
#     --> True:
#       Predict {0.0: 1}
#     --> False:
#       Is sepal length (cm) >= 7.9?
#       --> True:
#         Predict {2.0: 1}
#       --> False:
#         Is sepal width (cm) >= 4.1?
#         --> True:
#           Predict {0.0: 1}
#         --> False:
#           Is sepal width (cm) >= 4.0?
#           --> True:
#             Predict {0.0: 1}
#           --> False:
#             Is petal length (cm) >= 6.7?
#             --> True:
#               Predict {2.0: 2}
#             --> False:
#               Is petal length (cm) >= 6.6?
#               --> True:
#                 Predict {2.0: 1}
#               --> False:
#                 Is petal length (cm) >= 6.3?
#                 --> True:
#                   Predict {2.0: 1}
#                 --> False:
#                   Is sepal length (cm) >= 7.7?
#                   --> True:
#                     Predict {2.0: 1}
#                   --> False:
#                     Is sepal length (cm) >= 7.4?
#                     --> True:
#                       Predict {2.0: 1}
#                     --> False:
#                       Is petal length (cm) >= 6.1?
#                       --> True:
#                         Predict {2.0: 1}
#                       --> False:
#                         Is sepal width (cm) >= 3.9?
#                         --> True:
#                           Predict {0.0: 2}
#                         --> False:
#                           Is petal width (cm) >= 2.5?
#                           --> True:
#                             Predict {2.0: 2}
#                           --> False:
#                             Is petal length (cm) >= 6.0?
#                             --> True:
#                               Predict {2.0: 1}
#                             --> False:
#                               Is sepal length (cm) >= 7.2?
#                               --> True:
#                                 Predict {2.0: 1}
#                               --> False:
#                                 Is sepal length (cm) >= 7.1?
#                                 --> True:
#                                   Predict {2.0: 1}
#                                 --> False:
#                                   Is sepal length (cm) >= 7.0?
#                                   --> True:
#                                     Predict {1.0: 1}
#                                   --> False:
#                                     Is petal length (cm) >= 5.9?
#                                     --> True:
#                                       Predict {2.0: 1}
#                                     --> False:
#                                       Is petal length (cm) >= 5.8?
#                                       --> True:
#                                         Predict {2.0: 2}
#                                       --> False:
#                                         Is petal length (cm) >= 5.7?
#                                         --> True:
#                                           Predict {2.0: 2}
#                                         --> False:
#                                           Is petal width (cm) >= 2.4?
#                                           --> True:
#                                             Predict {2.0: 3}
#                                           --> False:
#                                             Is sepal width (cm) >= 3.8?
#                                             --> True:
#                                               Predict {0.0: 4}
#                                             --> False:
#                                               Is sepal width (cm) >= 3.7?
#                                               --> True:
#                                                 Predict {0.0: 3}
#                                               --> False:
#                                                 Is sepal width (cm) >= 3.6?
#                                                 --> True:
#                                                   Predict {0.0: 3}
#                                                 --> False:
#                                                   Is petal width (cm) >= 2.3?
#                                                   --> True:
#                                                     Predict {2.0: 4}
#                                                   --> False:
#                                                     Is petal width (cm) >= 2.2?
#                                                     --> True:
#                                                       Predict {2.0: 1}
#                                                     --> False:
#                                                       Is petal width (cm) >= 2.1?
#                                                       --> True:
#                                                         Predict {2.0: 3}
#                                                       --> False:
#                                                         Is sepal length (cm) >= 6.9?
#                                                         --> True:
#                                                           Predict {1.0: 1}
#                                                         --> False:
#                                                           Is sepal length (cm) >= 6.8?
#                                                           --> True:
#                                                             Predict {1.0: 1}
#                                                           --> False:
#                                                             Is sepal length (cm) >= 6.7?
#                                                             --> True:
#                                                               Predict {1.0: 3}
#                                                             --> False:
#                                                               Is sepal length (cm) >= 6.6?
#                                                               --> True:
#                                                                 Predict {1.0: 2}
#                                                               --> False:
#                                                                 Is petal length (cm) >= 5.6?
#                                                                 --> True:
#                                                                   Predict {2.0: 2}
#                                                                 --> False:
#                                                                   Is petal length (cm) >= 5.5?
#                                                                   --> True:
#                                                                     Predict {2.0: 2}
#                                                                   --> False:
#                                                                     Is petal length (cm) >= 5.3?
#                                                                     --> True:
#                                                                       Predict {2.0: 1}
#                                                                     --> False:
#                                                                       Is petal length (cm) >= 5.2?
#                                                                       --> True:
#                                                                         Predict {2.0: 1}
#                                                                       --> False:
#                                                                         Is petal width (cm) >= 2.0?
#                                                                         --> True:
#                                                                           Predict {2.0: 3}
#                                                                         --> False:
#                                                                           Is sepal length (cm) >= 6.5?
#                                                                           --> True:
#                                                                             Predict {1.0: 1}
#                                                                           --> False:
#                                                                             Is sepal length (cm) >= 6.4?
#                                                                             --> True:
#                                                                               Predict {1.0: 2}
#                                                                             --> False:
#                                                                               Is petal width (cm) >= 1.9?
#                                                                               --> True:
#                                                                                 Predict {2.0: 3}
#                                                                               --> False:
#                                                                                 Is sepal width (cm) >= 3.5?
#                                                                                 --> True:
#                                                                                   Predict {0.0: 6}
#                                                                                 --> False:
#                                                                                   Is sepal width (cm) >= 3.4?
#                                                                                   --> True:
#                                                                                     Is petal width (cm) >= 1.6?
#                                                                                     --> True:
#                                                                                       Predict {1.0: 1}
#                                                                                     --> False:
#                                                                                       Predict {0.0: 9}
#                                                                                   --> False:
#                                                                                     Is petal width (cm) >= 1.7?
#                                                                                     --> True:
#                                                                                       Is petal length (cm) >= 5.1?
#                                                                                       --> True:
#                                                                                         Predict {2.0: 1}
#                                                                                       --> False:
#                                                                                         Is sepal length (cm) >= 6.3?
#                                                                                         --> True:
#                                                                                           Predict {2.0: 1}
#                                                                                         --> False:
#                                                                                           Is petal length (cm) >= 4.9?
#                                                                                           --> True:
#                                                                                             Predict {2.0: 1}
#                                                                                           --> False:
#                                                                                             Is sepal length (cm) >= 6.2?
#                                                                                             --> True:
#                                                                                               Predict {2.0: 1}
#                                                                                             --> False:
#                                                                                               Is sepal length (cm) >= 6.0?
#                                                                                               --> True:
#                                                                                                 Predict {2.0: 1}
#                                                                                               --> False:
#                                                                                                 Is petal width (cm) >= 1.8?
#                                                                                                 --> True:
#                                                                                                   Predict {1.0: 1}
#                                                                                                 --> False:
#                                                                                                   Predict {2.0: 1}
#                                                                                     --> False:
#                                                                                       Is petal width (cm) >= 1.6?
#                                                                                       --> True:
#                                                                                         Predict {1.0: 2}
#                                                                                       --> False:
#                                                                                         Is petal length (cm) >= 5.1?
#                                                                                         --> True:
#                                                                                           Predict {2.0: 1}
#                                                                                         --> False:
#                                                                                           Is sepal length (cm) >= 6.3?
#                                                                                           --> True:
#                                                                                             Predict {1.0: 2}
#                                                                                           --> False:
#                                                                                             Is sepal length (cm) >= 6.2?
#                                                                                             --> True:
#                                                                                               Predict {1.0: 2}
#                                                                                             --> False:
#                                                                                               Is sepal length (cm) >= 6.1?
#                                                                                               --> True:
#                                                                                                 Predict {1.0: 4}
#                                                                                               --> False:
#                                                                                                 Is sepal width (cm) >= 3.3?
#                                                                                                 --> True:
#                                                                                                   Predict {0.0: 2}
#                                                                                                 --> False:
#                                                                                                   Is petal length (cm) >= 5.0?
#                                                                                                   --> True:
#                                                                                                     Predict {2.0: 1}
#                                                                                                   --> False:
#                                                                                                     Is sepal length (cm) >= 6.0?
#                                                                                                     --> True:
#                                                                                                       Predict {1.0: 2}
#                                                                                                     --> False:
#                                                                                                       Is sepal length (cm) >= 5.9?
#                                                                                                       --> True:
#                                                                                                         Predict {1.0: 1}
#                                                                                                       --> False:
#                                                                                                         Is petal width (cm) >= 1.5?
#                                                                                                         --> True:
#                                                                                                           Predict {1.0: 2}
#                                                                                                         --> False:
#                                                                                                           Is petal width (cm) >= 1.4?
#                                                                                                           --> True:
#                                                                                                             Predict {1.0: 1}
#                                                                                                           --> False:
#                                                                                                             Is petal length (cm) >= 4.5?
#                                                                                                             --> True:
#                                                                                                               Predict {1.0: 1}
#                                                                                                             --> False:
#                                                                                                               Is petal length (cm) >= 4.4?
#                                                                                                               --> True:
#                                                                                                                 Predict {1.0: 1}
#                                                                                                               --> False:
#                                                                                                                 Is petal length (cm) >= 4.2?
#                                                                                                                 --> True:
#                                                                                                                   Predict {1.0: 3}
#                                                                                                                 --> False:
#                                                                                                                   Is petal length (cm) >= 4.1?
#                                                                                                                   --> True:
#                                                                                                                     Predict {1.0: 3}
#                                                                                                                   --> False:
#                                                                                                                     Is sepal length (cm) >= 5.8?
#                                                                                                                     --> True:
#                                                                                                                       Predict {1.0: 2}
#                                                                                                                     --> False:
#                                                                                                                       Is sepal length (cm) >= 5.7?
#                                                                                                                       --> True:
#                                                                                                                         Predict {1.0: 1}
#                                                                                                                       --> False:
#                                                                                                                         Is sepal width (cm) >= 3.2?
#                                                                                                                         --> True:
#                                                                                                                           Predict {0.0: 5}
#                                                                                                                         --> False:
#                                                                                                                           Is petal length (cm) >= 4.0?
#                                                                                                                           --> True:
#                                                                                                                             Predict {1.0: 2}
#                                                                                                                           --> False:
#                                                                                                                             Is petal width (cm) >= 1.3?
#                                                                                                                             --> True:
#                                                                                                                               Predict {1.0: 1}
#                                                                                                                             --> False:
#                                                                                                                               Is petal length (cm) >= 3.9?
#                                                                                                                               --> True:
#                                                                                                                                 Predict {1.0: 1}
#                                                                                                                               --> False:
#                                                                                                                                 Is petal length (cm) >= 3.8?
#                                                                                                                                 --> True:
#                                                                                                                                   Predict {1.0: 1}
#                                                                                                                                 --> False:
#                                                                                                                                   Is sepal width (cm) >= 3.1?
#                                                                                                                                   --> True:
#                                                                                                                                     Predict {0.0: 4}
#                                                                                                                                   --> False:
#                                                                                                                                     Is petal width (cm) >= 1.1?
#                                                                                                                                     --> True:
#                                                                                                                                       Predict {1.0: 1}
#                                                                                                                                     --> False:
#                                                                                                                                       Is petal length (cm) >= 3.7?
#                                                                                                                                       --> True:
#                                                                                                                                         Predict {1.0: 1}
#                                                                                                                                       --> False:
#                                                                                                                                         Is petal length (cm) >= 3.5?
#                                                                                                                                         --> True:
#                                                                                                                                           Predict {1.0: 1}
#                                                                                                                                         --> False:
#                                                                                                                                           Is sepal width (cm) >= 3.0?
#                                                                                                                                           --> True:
#                                                                                                                                             Predict {0.0: 6}
#                                                                                                                                           --> False:
#                                                                                                                                             Is sepal length (cm) >= 5.0?
#                                                                                                                                             --> True:
#                                                                                                                                               Predict {1.0: 1}
#                                                                                                                                             --> False:
#                                                                                                                                               Is sepal width (cm) >= 2.9?
#                                                                                                                                               --> True:
#                                                                                                                                                 Predict {0.0: 1}
#                                                                                                                                               --> False:
#                                                                                                                                                 Is petal width (cm) >= 1.0?
#                                                                                                                                                 --> True:
#                                                                                                                                                   Predict {1.0: 1}
#                                                                                                                                                 --> False:
#                                                                                                                                                   Predict {0.0: 1}
